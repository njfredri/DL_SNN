# %% [markdown]
# import modules

# %%
import torch
from spikingjelly.activation_based import neuron
from spikingjelly import visualizing
from matplotlib import pyplot as plt

# %%
#deifine IF neurons layer
if_layer = neuron.IFNode()

# %%
#print hidden state or v
print(if_layer.v)
# Out:
# 0.0

# %%
#feeding in input will change the hidden state
x = torch.rand(size=[2, 3])
if_layer(x)
print(f'x.shape={x.shape}, if_layer.v.shape={if_layer.v.shape}')
# x.shape=torch.Size([2, 3]), if_layer.v.shape=torch.Size([2, 3])
if_layer.reset()

x = torch.rand(size=[4, 5, 6])
if_layer(x)
print(f'x.shape={x.shape}, if_layer.v.shape={if_layer.v.shape}')
# x.shape=torch.Size([4, 5, 6]), if_layer.v.shape=torch.Size([4, 5, 6])
if_layer.reset()
# Out:
# x.shape=torch.Size([2, 3]), if_layer.v.shape=torch.Size([2, 3])
# x.shape=torch.Size([4, 5, 6]), if_layer.v.shape=torch.Size([4, 5, 6])

# %% [markdown]
# Give the inputs to spiking neurons step-by-step. Check the membrane potential and output spikes, then plot them

# %%
if_layer.reset()
x = torch.as_tensor([0.02])
T = 150
s_list = []
v_list = []
for t in range(T):
    s_list.append(if_layer(x))
    v_list.append(if_layer.v)

dpi = 300
figsize = (12, 8)
visualizing.plot_one_neuron_v_s(torch.cat(v_list).numpy(), torch.cat(s_list).numpy(), v_threshold=if_layer.v_threshold,
                                v_reset=if_layer.v_reset,
                                figsize=figsize, dpi=dpi)
plt.show()

# %% [markdown]
# Give an input with shape=[32]. Then you can check the membrane potential and spikes of the 32 neurons

# %%
if_layer.reset()
T = 50
x = torch.rand([32]) / 8.
s_list = []
v_list = []
for t in range(T):
    s_list.append(if_layer(x).unsqueeze(0))
    v_list.append(if_layer.v.unsqueeze(0))

s_list = torch.cat(s_list)
v_list = torch.cat(v_list)

figsize = (12, 8)
dpi = 200
visualizing.plot_2d_heatmap(array=v_list.numpy(), title='membrane potentials', xlabel='simulating step',
                            ylabel='neuron index', int_x_ticks=True, x_max=T, figsize=figsize, dpi=dpi)


visualizing.plot_1d_spikes(spikes=s_list.numpy(), title='membrane sotentials', xlabel='simulating step',
                        ylabel='neuron index', figsize=figsize, dpi=dpi)

plt.show()

# %% [markdown]
# Change step_mode to multi-step.

# %%
import torch
from spikingjelly.activation_based import neuron, functional
if_layer = neuron.IFNode(step_mode='s')
T = 8
N = 2
x_seq = torch.rand([T, N])
y_seq = functional.multi_step_forward(x_seq, if_layer)
if_layer.reset()

if_layer.step_mode = 'm'
y_seq = if_layer(x_seq)
if_layer.reset()

# %% [markdown]
# Some neurons support cupy in multi-step mode. Cupy is really fast.

# %%
import torch
from spikingjelly.activation_based import neuron
if_layer = neuron.IFNode()
print(f'if_layer.backend={if_layer.backend}')
# if_layer.backend=torch

print(f'step_mode={if_layer.step_mode}, supported_backends={if_layer.supported_backends}')
# step_mode=s, supported_backends=('torch',)


if_layer.step_mode = 'm'
print(f'step_mode={if_layer.step_mode}, supported_backends={if_layer.supported_backends}')
# step_mode=m, supported_backends=('torch', 'cupy')

device = 'cuda:0'
if_layer.to(device)
if_layer.backend = 'cupy'  # switch to the cupy backend
print(f'if_layer.backend={if_layer.backend}')
# if_layer.backend=cupy

x_seq = torch.rand([8, 4], device=device)
y_seq = if_layer(x_seq)
if_layer.reset()
# Out:
# if_layer.backend=torch
# step_mode=s, supported_backends=('torch',)
# step_mode=m, supported_backends=('torch', 'cupy')
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\Fall2023\DeepLearning\SpikingJelly_Tutorials\tutorial_3.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/d%3A/Fall2023/DeepLearning/SpikingJelly_Tutorials/tutorial_3.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a> device = 'cuda:0'
#      <a href='vscode-notebook-cell:/d%3A/Fall2023/DeepLearning/SpikingJelly_Tutorials/tutorial_3.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a> if_layer.to(device)
# ---> <a href='vscode-notebook-cell:/d%3A/Fall2023/DeepLearning/SpikingJelly_Tutorials/tutorial_3.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a> if_layer.backend = 'cupy'  # switch to the cupy backend
#      <a href='vscode-notebook-cell:/d%3A/Fall2023/DeepLearning/SpikingJelly_Tutorials/tutorial_3.ipynb#X22sZmlsZQ%3D%3D?line=17'>18</a> print(f'if_layer.backend={if_layer.backend}')
#      <a href='vscode-notebook-cell:/d%3A/Fall2023/DeepLearning/SpikingJelly_Tutorials/tutorial_3.ipynb#X22sZmlsZQ%3D%3D?line=18'>19</a> # if_layer.backend=cupy
#
# File c:\Users\Njfre\.conda\envs\colab_env\lib\site-packages\spikingjelly\activation_based\base.py:342, in MemoryModule.__setattr__(self, name, value)
#     340     _memories[name] = value
#     341 else:
# --> 342     super().__setattr__(name, value)
#
# File c:\Users\Njfre\.conda\envs\colab_env\lib\site-packages\torch\nn\modules\module.py:1674, in Module.__setattr__(self, name, value)
#    1672     buffers[name] = value
#    1673 else:
# -> 1674     super().__setattr__(name, value)
#
# File c:\Users\Njfre\.conda\envs\colab_env\lib\site-packages\spikingjelly\activation_based\base.py:207, in MemoryModule.backend(self, value)
#     205 if value not in self.supported_backends:
#     206     raise NotImplementedError(f'{value} is not a supported backend of {self._get_name()}!')
# --> 207 check_backend_library(value)
#     208 self._backend = value
#
# File c:\Users\Njfre\.conda\envs\colab_env\lib\site-packages\spikingjelly\activation_based\base.py:43, in check_backend_library(backend)
#      41 elif backend == 'cupy':
#      42     if cupy is None:
# ---> 43         raise ImportError('CuPy is not installed! You can install it from "https://github.com/cupy/cupy".')
#      44 elif backend == 'lava':
#      45     if slayer is None:
#
# ImportError: CuPy is not installed! You can install it from "https://github.com/cupy/cupy".
